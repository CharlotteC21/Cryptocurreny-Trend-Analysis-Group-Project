# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as linregress
import numpy as np

# File to Load (Remember to Change These)
bitcoin = "BTC-USD.csv"
NVDA = "NVDA.csv"

# Read Purchasing File and store into Pandas data frame
bitcoin_df = pd.read_csv(bitcoin)
print(bitcoin_df.head())
nvda_df = pd.read_csv(NVDA)
print(nvda_df.head())
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  10/30/2016  714.117981  714.117981  696.474976  701.864014  701.864014
# 1  10/31/2016  702.640015  709.289001  691.682007  700.971985  700.971985
# 2   11/1/2016  701.336975  736.452026  701.336975  729.793030  729.793030
# 3   11/2/2016  730.065979  740.828979  722.348999  740.828979  740.828979
# 4   11/3/2016  742.346008  745.773010  678.156006  688.700012  688.700012
#
#         Volume
# 0  100665000.0
# 1   97064400.0
# 2  130527000.0
# 3   84865200.0
# 4  172808000.0
#          Date       Open       High      Low      Close  Adj Close    Volume
# 0  10/31/2016  17.697500  17.907499  17.6875  17.790001  17.534466  25238800
# 1   11/1/2016  17.855000  17.952499  17.0725  17.262501  17.014545  47322400
# 2   11/2/2016  17.395000  17.629999  17.1600  17.190001  16.943089  29584800
# 3   11/3/2016  17.270000  17.285000  16.6600  16.990000  16.745955  30966400
# 4   11/4/2016  16.877501  17.182501  16.6450  16.892500  16.649858  32878000

# %%
dates = bitcoin_df["Date"]
close_price = bitcoin_df["Close"]

plt.plot(dates, close_price, color="green", label="Bitcoin Price")
plt.legend(loc="best")
plt.title("Bitcoin Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

dates = nvda_df["Date"]
close_price = nvda_df["Close"]

plt.plot(dates, close_price, color="green", label="NVDA Price")
plt.legend(loc="best")
plt.title("NVDA Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
print(bit_close_price.count())
print(nvda_close_price.count())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34572/799205948.py in <module>
# ----> 1 print(bit_close_price.count())
#       2 print(nvda_close_price.count())
#
# NameError: name 'bit_close_price' is not defined

# %%
bit_close_price = bitcoin_df_2020["Close"]
nvda_close_price = nvda_df["Close"]

plt.scatter(bit_close_price, nvda_close_price, color="green", label="NVDA Price")
plt.legend(loc="best")
plt.title("NVDA vs Bitcoin Price")
plt.xlabel("Bitcoin")
plt.ylabel("NVDA")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34572/1563030693.py in <module>
# ----> 1 bit_close_price = bitcoin_df_2020["Close"]
#       2 nvda_close_price = nvda_df["Close"]
#       3
#       4 plt.scatter(bit_close_price, nvda_close_price, color="green", label="NVDA Price")
#       5 plt.legend(loc="best")
#
# NameError: name 'bitcoin_df_2020' is not defined

# %%
nvda_close_price = nvda_close_price.loc[(nvda_close_price["Date"] > "10/31/2016") & (nvda_close_price["Date"] > "10/29/2021")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6976/2656901330.py in <module>
# ----> 1 nvda_close_price = nvda_close_price.loc[(nvda_close_price["Date"] > "10/31/2016") & (nvda_close_price["Date"] > "10/29/2021")]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#     390
#
# KeyError: 'Date'
